# %%
import pandas as pd
import numpy as np
import talib as ta
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
df = pd.read_csv('aususd_6m_may9th.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34192 entries, 0 to 34191
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  34192 non-null  object
#  1   Open      34192 non-null  float64
#  2   High      34192 non-null  float64
#  3   Low       34192 non-null  float64
#  4   Close     34192 non-null  float64
#  5   Volume    34192 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#               DateTime     Open     High      Low    Close     Volume
# 0  2020-11-09 00:00:00  0.72861  0.72886  0.72844  0.72860  662689984
# 1  2020-11-09 00:05:00  0.72860  0.72870  0.72794  0.72797  797062016
# 2  2020-11-09 00:10:00  0.72796  0.72817  0.72765  0.72791  805720000
# 3  2020-11-09 00:15:00  0.72791  0.72812  0.72768  0.72785  754724992
# 4  2020-11-09 00:20:00  0.72784  0.72828  0.72778  0.72791  836700032

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])

# %%
df.head()
# Out:
#              DateTime     Open     High      Low    Close     Volume
# 0 2020-11-09 00:00:00  0.72861  0.72886  0.72844  0.72860  662689984
# 1 2020-11-09 00:05:00  0.72860  0.72870  0.72794  0.72797  797062016
# 2 2020-11-09 00:10:00  0.72796  0.72817  0.72765  0.72791  805720000
# 3 2020-11-09 00:15:00  0.72791  0.72812  0.72768  0.72785  754724992
# 4 2020-11-09 00:20:00  0.72784  0.72828  0.72778  0.72791  836700032

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34192 entries, 0 to 34191
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  34192 non-null  datetime64[ns]
#  1   Open      34192 non-null  float64
#  2   High      34192 non-null  float64
#  3   Low       34192 non-null  float64
#  4   Close     34192 non-null  float64
#  5   Volume    34192 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 1.6 MB

# %%
df = df.set_index('DateTime')

# %%
df['Simple MA'] = ta.SMA(df['Close'],14)
df['EMA'] = ta.EMA(df['Close'], timeperiod = 14)

# %%
df.head()
# Out:
#                         Open     High      Low    Close     Volume  Simple MA  \
# DateTime
# 2020-11-09 00:00:00  0.72861  0.72886  0.72844  0.72860  662689984        NaN
# 2020-11-09 00:05:00  0.72860  0.72870  0.72794  0.72797  797062016        NaN
# 2020-11-09 00:10:00  0.72796  0.72817  0.72765  0.72791  805720000        NaN
# 2020-11-09 00:15:00  0.72791  0.72812  0.72768  0.72785  754724992        NaN
# 2020-11-09 00:20:00  0.72784  0.72828  0.72778  0.72791  836700032        NaN
#
#                      EMA
# DateTime
# 2020-11-09 00:00:00  NaN
# 2020-11-09 00:05:00  NaN
# 2020-11-09 00:10:00  NaN
# 2020-11-09 00:15:00  NaN
# 2020-11-09 00:20:00  NaN

# %%
import mplfinance as mpf

# %%
df['2020-12-01':'2020-12-31']
# Out:
#                         Open     High      Low    Close     Volume  Simple MA  \
# DateTime
# 2020-12-01 00:00:00  0.73588  0.73599  0.73557  0.73566  728150016   0.735188
# 2020-12-01 00:05:00  0.73568  0.73573  0.73542  0.73566  501200000   0.735272
# 2020-12-01 00:10:00  0.73567  0.73567  0.73540  0.73552  379849984   0.735329
# 2020-12-01 00:15:00  0.73553  0.73557  0.73523  0.73543  517905984   0.735379
# 2020-12-01 00:20:00  0.73544  0.73551  0.73534  0.73549  363004000   0.735436
# ...                      ...      ...      ...      ...        ...        ...
# 2020-12-31 20:35:00  0.77106  0.77117  0.77099  0.77100  118750000   0.770625
# 2020-12-31 20:40:00  0.77101  0.77109  0.77089  0.77091  170224992   0.770659
# 2020-12-31 20:45:00  0.77092  0.77095  0.77066  0.77078  188100000   0.770679
# 2020-12-31 20:50:00  0.77078  0.77095  0.77075  0.77095  327849984   0.770711
# 2020-12-31 20:55:00  0.77094  0.77113  0.77077  0.77091  421524992   0.770747
#
#                           EMA
# DateTime
# 2020-12-01 00:00:00  0.735344
# 2020-12-01 00:05:00  0.735386
# 2020-12-01 00:10:00  0.735404
# 2020-12-01 00:15:00  0.735408
# 2020-12-01 00:20:00  0.735419
# ...                       ...
# 2020-12-31 20:35:00  0.770641
# 2020-12-31 20:40:00  0.770677
# 2020-12-31 20:45:00  0.770691
# 2020-12-31 20:50:00  0.770725
# 2020-12-31 20:55:00  0.770750
#
# [6155 rows x 7 columns]

# %%
tcdf = df['2020-12-01 01:00:00':'2020-12-02 01:00:00'][['Simple MA','EMA']]  # DataFrame with two columns
apd  = mpf.make_addplot(tcdf)
mpf.plot(df['2020-12-01 01:00:00':'2020-12-02 01:00:00'], type='candle', title='GBPUSD represented by candlesticks', figratio=(22,10))
mpf.plot(df['2020-12-01 01:00:00':'2020-12-02 01:00:00'], type='candle', title='GBPUSD with moving averages', figratio=(22,10), addplot=apd)

# mpf.plot(stored_df['09-25-2020':'10-01-2020'],type='candle',volume=False,
#          show_nontrading=False, figratio=(16,10), style='charles', addplot=apd)
# Out:
# C:\Users\Neel\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Neel\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
