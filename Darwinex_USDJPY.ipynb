# %%
import pandas as pd
import numpy as np
import talib as ta
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
df = pd.read_csv('usdjpy_6m_may9th.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33680 entries, 0 to 33679
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  33680 non-null  object
#  1   Open      33680 non-null  float64
#  2   High      33680 non-null  float64
#  3   Low       33680 non-null  float64
#  4   Close     33680 non-null  float64
#  5   Volume    33680 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.5+ MB

# %%
df.head()
# Out:
#               DateTime     Open     High      Low    Close      Volume
# 0  2020-11-09 00:00:00  103.254  103.286  103.238  103.259  1069652992
# 1  2020-11-09 00:05:00  103.259  103.311  103.259  103.308  1035225024
# 2  2020-11-09 00:10:00  103.307  103.332  103.291  103.297  1525969024
# 3  2020-11-09 00:15:00  103.297  103.324  103.275  103.275  1080601984
# 4  2020-11-09 00:20:00  103.275  103.287  103.242  103.287   754400000

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])

# %%
df.head()
# Out:
#              DateTime     Open     High      Low    Close      Volume
# 0 2020-11-09 00:00:00  103.254  103.286  103.238  103.259  1069652992
# 1 2020-11-09 00:05:00  103.259  103.311  103.259  103.308  1035225024
# 2 2020-11-09 00:10:00  103.307  103.332  103.291  103.297  1525969024
# 3 2020-11-09 00:15:00  103.297  103.324  103.275  103.275  1080601984
# 4 2020-11-09 00:20:00  103.275  103.287  103.242  103.287   754400000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33680 entries, 0 to 33679
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  33680 non-null  datetime64[ns]
#  1   Open      33680 non-null  float64
#  2   High      33680 non-null  float64
#  3   Low       33680 non-null  float64
#  4   Close     33680 non-null  float64
#  5   Volume    33680 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 1.5 MB

# %%
df = df.set_index('DateTime')

# %%
df['Simple MA'] = ta.SMA(df['Close'],14)
df['EMA'] = ta.EMA(df['Close'], timeperiod = 14)

# %%
df.head()
# Out:
#                         Open     High      Low    Close      Volume  \
# DateTime
# 2020-11-09 00:00:00  103.254  103.286  103.238  103.259  1069652992
# 2020-11-09 00:05:00  103.259  103.311  103.259  103.308  1035225024
# 2020-11-09 00:10:00  103.307  103.332  103.291  103.297  1525969024
# 2020-11-09 00:15:00  103.297  103.324  103.275  103.275  1080601984
# 2020-11-09 00:20:00  103.275  103.287  103.242  103.287   754400000
#
#                      Simple MA  EMA
# DateTime
# 2020-11-09 00:00:00        NaN  NaN
# 2020-11-09 00:05:00        NaN  NaN
# 2020-11-09 00:10:00        NaN  NaN
# 2020-11-09 00:15:00        NaN  NaN
# 2020-11-09 00:20:00        NaN  NaN

# %%
import mplfinance as mpf

# %%
df['2020-12-01':'2020-12-31']
# Out:
#                         Open     High      Low    Close      Volume  \
# DateTime
# 2020-12-01 00:00:00  104.304  104.352  104.285  104.346  1247223040
# 2020-12-01 00:05:00  104.346  104.372  104.345  104.362   471449984
# 2020-12-01 00:10:00  104.362  104.369  104.333  104.340   686275008
# 2020-12-01 00:15:00  104.340  104.363  104.339  104.353   437484000
# 2020-12-01 00:20:00  104.354  104.363  104.350  104.351   297377984
# ...                      ...      ...      ...      ...         ...
# 2020-12-31 20:35:00  103.255  103.256  103.250  103.254   250500000
# 2020-12-31 20:40:00  103.254  103.260  103.251  103.260   142500000
# 2020-12-31 20:45:00  103.259  103.276  103.259  103.275   140250000
# 2020-12-31 20:50:00  103.274  103.275  103.250  103.250   252000000
# 2020-12-31 20:55:00  103.250  103.257  103.250  103.255   443000000
#
#                       Simple MA         EMA
# DateTime
# 2020-12-01 00:00:00  104.328071  104.320945
# 2020-12-01 00:05:00  104.329500  104.326419
# 2020-12-01 00:10:00  104.329429  104.328230
# 2020-12-01 00:15:00  104.329143  104.331532
# 2020-12-01 00:20:00  104.329857  104.334128
# ...                         ...         ...
# 2020-12-31 20:35:00  103.259714  103.259267
# 2020-12-31 20:40:00  103.260643  103.259365
# 2020-12-31 20:45:00  103.262643  103.261450
# 2020-12-31 20:50:00  103.263071  103.259923
# 2020-12-31 20:55:00  103.262786  103.259267
#
# [6154 rows x 7 columns]

# %%
tcdf = df['2020-12-01 01:00:00':'2020-12-02 01:00:00'][['Simple MA','EMA']]  # DataFrame with two columns
apd  = mpf.make_addplot(tcdf)
mpf.plot(df['2020-12-01 01:00:00':'2020-12-02 01:00:00'], type='candle', title='GBPUSD represented by candlesticks', figratio=(22,10))
mpf.plot(df['2020-12-01 01:00:00':'2020-12-02 01:00:00'], type='candle', title='GBPUSD with moving averages', figratio=(22,10), addplot=apd)

# mpf.plot(stored_df['09-25-2020':'10-01-2020'],type='candle',volume=False,
#          show_nontrading=False, figratio=(16,10), style='charles', addplot=apd)
# Out:
# C:\Users\Neel\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Neel\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
