# %%
import pandas as pd
import numpy as np
import talib as ta
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
df = pd.read_csv('nzdusd_6m_may9th.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34179 entries, 0 to 34178
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  34179 non-null  object
#  1   Open      34179 non-null  float64
#  2   High      34179 non-null  float64
#  3   Low       34179 non-null  float64
#  4   Close     34179 non-null  float64
#  5   Volume    34179 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#               DateTime     Open     High      Low    Close     Volume
# 0  2020-11-09 00:00:00  0.67963  0.68016  0.67962  0.68003  436536992
# 1  2020-11-09 00:05:00  0.68004  0.68007  0.67927  0.67932  491750016
# 2  2020-11-09 00:10:00  0.67932  0.67944  0.67902  0.67924  432752000
# 3  2020-11-09 00:15:00  0.67923  0.67944  0.67915  0.67938  376249984
# 4  2020-11-09 00:20:00  0.67939  0.67977  0.67935  0.67954  544806016

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])

# %%
df.head()
# Out:
#              DateTime     Open     High      Low    Close     Volume
# 0 2020-11-09 00:00:00  0.67963  0.68016  0.67962  0.68003  436536992
# 1 2020-11-09 00:05:00  0.68004  0.68007  0.67927  0.67932  491750016
# 2 2020-11-09 00:10:00  0.67932  0.67944  0.67902  0.67924  432752000
# 3 2020-11-09 00:15:00  0.67923  0.67944  0.67915  0.67938  376249984
# 4 2020-11-09 00:20:00  0.67939  0.67977  0.67935  0.67954  544806016

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34179 entries, 0 to 34178
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  34179 non-null  datetime64[ns]
#  1   Open      34179 non-null  float64
#  2   High      34179 non-null  float64
#  3   Low       34179 non-null  float64
#  4   Close     34179 non-null  float64
#  5   Volume    34179 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 1.6 MB

# %%
df = df.set_index('DateTime')

# %%
df['Simple MA'] = ta.SMA(df['Close'],14)
df['EMA'] = ta.EMA(df['Close'], timeperiod = 14)

# %%
df.head()
# Out:
#                         Open     High      Low    Close     Volume  Simple MA  \
# DateTime
# 2020-11-09 00:00:00  0.67963  0.68016  0.67962  0.68003  436536992        NaN
# 2020-11-09 00:05:00  0.68004  0.68007  0.67927  0.67932  491750016        NaN
# 2020-11-09 00:10:00  0.67932  0.67944  0.67902  0.67924  432752000        NaN
# 2020-11-09 00:15:00  0.67923  0.67944  0.67915  0.67938  376249984        NaN
# 2020-11-09 00:20:00  0.67939  0.67977  0.67935  0.67954  544806016        NaN
#
#                      EMA
# DateTime
# 2020-11-09 00:00:00  NaN
# 2020-11-09 00:05:00  NaN
# 2020-11-09 00:10:00  NaN
# 2020-11-09 00:15:00  NaN
# 2020-11-09 00:20:00  NaN

# %%
import mplfinance as mpf

# %%
df['2020-12-01':'2020-12-31']
# Out:
#                         Open     High      Low    Close     Volume  Simple MA  \
# DateTime
# 2020-12-01 00:00:00  0.70187  0.70201  0.70186  0.70197  345300000   0.701609
# 2020-12-01 00:05:00  0.70198  0.70213  0.70190  0.70212  362449984   0.701684
# 2020-12-01 00:10:00  0.70212  0.70217  0.70200  0.70216  433249984   0.701743
# 2020-12-01 00:15:00  0.70217  0.70222  0.70199  0.70220  156824992   0.701800
# 2020-12-01 00:20:00  0.70221  0.70232  0.70218  0.70227   96600000   0.701866
# ...                      ...      ...      ...      ...        ...        ...
# 2020-12-31 20:35:00  0.71977  0.71983  0.71970  0.71970  119500000   0.719584
# 2020-12-31 20:40:00  0.71971  0.71981  0.71967  0.71968  106000000   0.719614
# 2020-12-31 20:45:00  0.71967  0.71971  0.71958  0.71967  114750000   0.719629
# 2020-12-31 20:50:00  0.71967  0.71975  0.71958  0.71961  312249984   0.719639
# 2020-12-31 20:55:00  0.71961  0.71973  0.71947  0.71956  229750000   0.719643
#
#                           EMA
# DateTime
# 2020-12-01 00:00:00  0.701701
# 2020-12-01 00:05:00  0.701757
# 2020-12-01 00:10:00  0.701811
# 2020-12-01 00:15:00  0.701863
# 2020-12-01 00:20:00  0.701917
# ...                       ...
# 2020-12-31 20:35:00  0.719554
# 2020-12-31 20:40:00  0.719571
# 2020-12-31 20:45:00  0.719584
# 2020-12-31 20:50:00  0.719588
# 2020-12-31 20:55:00  0.719584
#
# [6151 rows x 7 columns]

# %%
tcdf = df['2020-12-01 01:00:00':'2020-12-02 01:00:00'][['Simple MA','EMA']]  # DataFrame with two columns
apd  = mpf.make_addplot(tcdf)
mpf.plot(df['2020-12-01 01:00:00':'2020-12-02 01:00:00'], type='candle', title='GBPUSD represented by candlesticks', figratio=(22,10))
mpf.plot(df['2020-12-01 01:00:00':'2020-12-02 01:00:00'], type='candle', title='GBPUSD with moving averages', figratio=(22,10), addplot=apd)

# mpf.plot(stored_df['09-25-2020':'10-01-2020'],type='candle',volume=False,
#          show_nontrading=False, figratio=(16,10), style='charles', addplot=apd)
# Out:
# C:\Users\Neel\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:2062: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Neel\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:250: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
